# %%
import json
from collections import defaultdict

import agama
import cmasher as cmr
import gc_utils
import h5py
import halo_analysis as halo
import matplotlib as mpl
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import utilities as ut
from astropy.stats import biweight_location
from matplotlib import cm
from matplotlib.animation import PillowWriter
from matplotlib.cm import ScalarMappable
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import LogLocator
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter1d, zoom
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy.stats import binned_statistic_2d
from sklearn import cluster as cl
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# | Metric        | Meaning                                                                   |
# | ------------- | ------------------------------------------------------------------------- |
# | **Precision** | Of the predicted class instances, how many were correct? (TP / (TP + FP)) |
# | **Recall**    | Of the actual class instances, how many were retrieved? (TP / (TP + FN))  |
# | **F1-score**  | Harmonic mean of precision and recall. Good overall performance measure.  |
# | **Support**   | Number of true instances for each class.                                  |

# %%
sim = "m12i"
# group_id = 1920378
disk_form = 4

# about 2 minutes to run on 101 iterations
it_min = 0
it_max = 100

snap_lim = 60  # m12i: 60, m12f:
cluster_type = "birch"

# variables = ["et", "jr", "jp", "jz"]
variables = ["et_norm", "jr", "jp", "jz"]
n_clusters = 2

# %%
agama.setUnits(mass=1, length=1, velocity=1)

# snap_lim = 46
sim_dir = "/Users/z5114326/Documents/simulations/"
# sim_dir = "/Volumes/One_Touch/simulations/"
# sim_dir = "/Volumes/Expansion/simulations/"

fire_dir = sim_dir + sim + "/" + sim + "_res7100"

pub_data = sim_dir + "snapshot_times_public.txt"
pub_snaps = pd.read_table(pub_data, comment="#", header=None, sep=r"\s+")
pub_snaps.columns = [
    "index",
    "scale_factor",
    "redshift",
    "time_Gyr",
    "lookback_time_Gyr",
    "time_width_Myr",
]
snap_lst = pub_snaps["index"].to_numpy()
time_lst = pub_snaps["time_Gyr"].to_numpy()

snap_lst = pub_snaps[pub_snaps["index"] >= snap_lim]["index"].to_numpy()
time_lst = pub_snaps[pub_snaps["index"] >= snap_lim]["time_Gyr"].to_numpy()

all_data = sim_dir + "/" + sim + "/" + sim + "_res7100/" + "snapshot_times.txt"
all_snaps = pd.read_table(all_data, comment="#", header=None, sep=r"\s+")
all_snaps.columns = [
    "index",
    "scale_factor",
    "redshift",
    "time_Gyr",
    "lookback_time_Gyr",
    "time_width_Myr",
]

proc_file = sim_dir + sim + "/" + sim + "_processed.hdf5"
proc_data = h5py.File(proc_file, "r")  # open processed data file

grp_file = sim_dir + sim + "/" + "gc_groups.json"
with open(grp_file, "r") as file:
    grp_col_dict = json.load(file)

grp_lst = [int(grp) for grp in grp_col_dict[sim].keys()]
grp_lst
# Out:
# [0, 1920378, 4414957, 8580896, 13687078, 16199669, 19898495]

# %%
# if group_id not in grp_lst:
#     raise ValueError(f"group_id {group_id} not found in grp_lst")

# %% [markdown]
# # Functions

# %%
def clustering(X, rnd_grps, n_clusters, cluster_type):
    scaler = StandardScaler()
    X_scal = scaler.fit_transform(X)

    if cluster_type == "kmeans":
        kmeans = cl.KMeans(n_clusters=n_clusters, random_state=0).fit(X_scal)
        labels = kmeans.labels_

    if cluster_type == "agglom":
        agglom = cl.AgglomerativeClustering(n_clusters=n_clusters).fit(X_scal)
        labels = agglom.labels_

    if cluster_type == "birch":
        birch = cl.Birch(n_clusters=n_clusters, threshold=0.2).fit(X_scal)
        labels = birch.labels_

    count = 0
    for label in range(n_clusters):
        label_msk = labels == label

        # Get group ID counts for accreted particles in this cluster
        grp_lst_acc = np.abs(rnd_grps[label_msk])
        unique_acc, counts_acc = np.unique(grp_lst_acc, return_counts=True)
        count_dict_acc = dict(zip(unique_acc, counts_acc))

        # Identify the most common group
        grp_identified = unique_acc[np.argmax(counts_acc)]

        if count_dict_acc[grp_identified] > count:
            count = count_dict_acc[grp_identified]
            grp_label = label
            pred_grp = grp_identified

    return pred_grp, grp_label, labels

# %%
def clustering_envelope(it, snap, proc_data, n_clusters, variables, cluster_type):
    it_id = gc_utils.iteration_name(it)
    snap_id = gc_utils.snapshot_name(snap)

    snp_dat = proc_data[it_id]["snapshots"][snap_id]
    acc_msk = snp_dat["now_accreted"][()] == 1
    bnd_msk = snp_dat["bound_flag"][()] == 1

    full_grps = np.abs(snp_dat["group_id"][acc_msk & bnd_msk])
    full_gcid = snp_dat["gc_id"][acc_msk & bnd_msk]

    rnd_grps = full_grps.copy()
    rnd_gcid = full_gcid.copy()

    unq_grp, cnt_grp = np.unique(full_grps, return_counts=True)
    grp_cnt_dict = dict(zip(unq_grp, cnt_grp))

    # res_dict = {
    #     gc_id: {"True": grp, "Pred": None} if grp in grp_lst else {"True": -1, "Pred": None}
    #     for gc_id, grp in zip(full_gcid, full_grps)
    # }

    # res_dict = {gc_id: {"True": grp, "Pred": None} for gc_id, grp in zip(full_gcid, full_grps)}

    res_dict = {
        gc_id: {"True": grp, "Pred": None} if grp_cnt_dict[grp] >= 5 else {"True": -1, "Pred": None}
        for gc_id, grp in zip(full_gcid, full_grps)
    }

    X_init = np.column_stack(
        [
            snp_dat["j.cyl"][:, 2][acc_msk & bnd_msk]
            if var == "jz"
            else snp_dat["j.cyl"][:, 1][acc_msk & bnd_msk]
            if var == "jp"
            else snp_dat["j.cyl"][:, 0][acc_msk & bnd_msk]
            if var == "jr"
            else snp_dat[var][acc_msk & bnd_msk]
            for var in variables
        ]
    )

    X = X_init

    while len(X) >= 5:
        pred_grp, grp_label, labels = clustering(X, rnd_grps, n_clusters, cluster_type)

        lab_msk = labels == grp_label
        gc_filt = rnd_gcid[lab_msk]

        for gc_id in gc_filt:
            res_dict[gc_id]["Pred"] = pred_grp

        rnd_grps = rnd_grps[~lab_msk]
        rnd_gcid = rnd_gcid[~lab_msk]
        X = X[~lab_msk]

    # group remaining gc's as other (-1)
    for gc_id in rnd_gcid:
        res_dict[gc_id]["Pred"] = -1

    return res_dict

# %%
def calc_entropy(p):
    """Compute Shannon entropy of a probability distribution p."""
    p = p[p > 0]  # filter out zeros to avoid log(0)
    return -np.sum(p * np.log2(p))


def clustering_entropy(true_labels, predicted_labels):
    labels = np.unique(np.concatenate((np.array(true_labels), np.array(predicted_labels))))
    cm = confusion_matrix(true_labels, predicted_labels, labels=labels)
    total = cm.sum()

    weighted_entropies = [] = []
    entropy_by_cluster = {}

    for i, col in enumerate(cm.T):  # loop over predicted clusters
        cluster_label = labels[i]
        cluster_total = np.sum(col)

        if cluster_total == 0:
            entropy_by_cluster[cluster_label] = 0.0
            weighted_entropies.append(0.0)
            continue

        p = col / cluster_total
        e = calc_entropy(p)
        weight = cluster_total / total

        entropy_by_cluster[cluster_label] = e / np.log2(cm.shape[1])
        weighted_entropies.append(weight * e)

    total_entropy = np.sum(weighted_entropies)

    # print(entropy_by_cluster)
    return total_entropy

# %%
# High F1 -> clear kinematic signature of a group (well-recovered).
# Low F1 -> the group is either mixed, fragmented, or indistinct.


def get_classifications(true_grp, pred_grp):
    report = classification_report(true_grp, pred_grp, output_dict=True, zero_division=0)

    class_dict = {}
    class_dict["macro_reca"] = report["macro avg"]["recall"]
    class_dict["macro_prec"] = report["macro avg"]["precision"]
    class_dict["macro_f1"] = report["macro avg"]["f1-score"]

    return report

# %%
def snapshot_clustering(it, proc_data, cluster_type, n_clusters, variables, snap_lst):
    snap_dict = {}
    snap_dict["entropy"] = []
    snap_dict["accuracy"] = []
    snap_dict["weight_recall"] = []
    snap_dict["macro_recall"] = []
    snap_dict["weight_precision"] = []
    snap_dict["macro_precision"] = []
    snap_dict["weight_f1"] = []
    snap_dict["macro_f1"] = []

    for snap in snap_lst:
        res_dict = clustering_envelope(it, snap, proc_data, n_clusters, variables, cluster_type)

        true_grp = [res_dict[gc_id]["True"] for gc_id in res_dict.keys()]
        pred_grp = [res_dict[gc_id]["Pred"] for gc_id in res_dict.keys()]

        entropy = clustering_entropy(true_grp, pred_grp)
        num_grps = len(np.unique(np.concatenate((true_grp, pred_grp))))
        entropy_norm = entropy / np.log2(num_grps)
        snap_dict["entropy"].append(entropy_norm)

        report = classification_report(true_grp, pred_grp, output_dict=True, zero_division=0)
        snap_dict["accuracy"].append(report["accuracy"])
        snap_dict["weight_recall"].append(report["weighted avg"]["recall"])
        snap_dict["macro_recall"].append(report["macro avg"]["recall"])
        snap_dict["weight_precision"].append(report["weighted avg"]["precision"])
        snap_dict["macro_precision"].append(report["macro avg"]["precision"])
        snap_dict["weight_f1"].append(report["weighted avg"]["f1-score"])
        snap_dict["macro_f1"].append(report["macro avg"]["f1-score"])

    return snap_dict

# %%
def iteration_clustering(it_lst, cluster_type, n_clusters, variables, sim, sim_dir, snap_lim):
    proc_file = sim_dir + sim + "/" + sim + "_processed.hdf5"
    proc_data = h5py.File(proc_file, "r")  # open processed data file

    pub_data = sim_dir + "snapshot_times_public.txt"
    pub_snaps = pd.read_table(pub_data, comment="#", header=None, sep=r"\s+")
    pub_snaps.columns = [
        "index",
        "scale_factor",
        "redshift",
        "time_Gyr",
        "lookback_time_Gyr",
        "time_width_Myr",
    ]

    snap_lst = pub_snaps["index"].values
    snap_lst = snap_lst[snap_lst >= snap_lim]
    time_lst = [pub_snaps[pub_snaps["index"] == snap]["time_Gyr"].values[0] for snap in snap_lst]

    # ent_it_lst = []
    it_dict = defaultdict(list)

    for it in it_lst:
        snap_dict = snapshot_clustering(it, proc_data, cluster_type, n_clusters, variables, snap_lst)
        for metric in snap_dict.keys():
            it_dict[metric].append(snap_dict[metric])

    cluster_dict = {
        "snap": snap_lst,
        "time": time_lst,
    }

    # Add mean and std of each metric across iterations
    for metric in it_dict.keys():
        cluster_dict[f"{metric}_avg"] = np.nanmean(it_dict[metric], axis=0)
        cluster_dict[f"{metric}_std"] = np.nanstd(it_dict[metric], axis=0)

    return cluster_dict

# %%
def averaged_metric(report, group_keys, metric="f1-score", exclude_group="0"):
    total_w_sum = 0.0
    total_m_sum = 0.0
    total_counts = 0

    num_grps = len(group_keys) - 1

    for group in group_keys:
        if group == exclude_group:
            continue

        value = report[group][metric]
        count = report[group]["support"]

        total_w_sum += value * count
        total_m_sum += value
        total_counts += count

    if total_counts == 0:
        w_avg = np.nan
        m_avg = np.nan
    else:
        w_avg = total_w_sum / total_counts
        m_avg = total_m_sum / num_grps

    return w_avg, m_avg

# %%
def group_snap_clustering(it, proc_data, cluster_type, n_clusters, variables, snap_lst):
    group_dict = {}
    for snap in snap_lst:
        res_dict = clustering_envelope(it, snap, proc_data, n_clusters, variables, cluster_type)

        true_grp = [res_dict[gc_id]["True"] for gc_id in res_dict.keys()]
        pred_grp = [res_dict[gc_id]["Pred"] for gc_id in res_dict.keys()]

        report = classification_report(true_grp, pred_grp, output_dict=True, zero_division=0)

        group_keys = [k for k in report.keys() if not any(c.isalpha() for c in str(k))]
        for group in group_keys:
            if group not in group_dict.keys():
                group_dict[group] = {"snap": [], "recall": [], "precision": [], "f1": []}

            group_dict[group]["snap"].append(snap)
            group_dict[group]["recall"].append(report[group]["recall"])
            group_dict[group]["precision"].append(report[group]["precision"])
            group_dict[group]["f1"].append(report[group]["f1-score"])

        if "ex_situ" not in group_dict.keys():
            group_dict["ex_situ"] = {
                "snap": [],
                "weight_recall": [],
                "macro_recall": [],
                "weight_precision": [],
                "macro_precision": [],
                "weight_f1": [],
                "macro_f1": [],
            }

        w_r, m_r = averaged_metric(report, group_keys, metric="recall")
        w_p, m_p = averaged_metric(report, group_keys, metric="precision")
        w_f, m_f = averaged_metric(report, group_keys, metric="f1-score")

        group_dict["ex_situ"]["snap"].append(snap)
        group_dict["ex_situ"]["weight_recall"].append(w_r)
        group_dict["ex_situ"]["macro_recall"].append(m_r)
        group_dict["ex_situ"]["weight_precision"].append(w_p)
        group_dict["ex_situ"]["macro_precision"].append(m_p)
        group_dict["ex_situ"]["weight_f1"].append(w_f)
        group_dict["ex_situ"]["macro_f1"].append(m_f)

    return group_dict

# %%
def group_iteration_clustering(it_lst, cluster_type, n_clusters, variables, sim, sim_dir, snap_lim):
    proc_file = sim_dir + sim + "/" + sim + "_processed.hdf5"
    proc_data = h5py.File(proc_file, "r")  # open processed data file

    pub_data = sim_dir + "snapshot_times_public.txt"
    pub_snaps = pd.read_table(pub_data, comment="#", header=None, sep=r"\s+")
    pub_snaps.columns = [
        "index",
        "scale_factor",
        "redshift",
        "time_Gyr",
        "lookback_time_Gyr",
        "time_width_Myr",
    ]

    snap_lst = pub_snaps["index"].values
    snap_lst = snap_lst[snap_lst >= snap_lim]
    time_lst = [pub_snaps[pub_snaps["index"] == snap]["time_Gyr"].values[0] for snap in snap_lst]

    # ent_it_lst = []
    # it_dict = defaultdict(list)
    it_dict = {}

    for it in it_lst:
        grp_snap_dict = group_snap_clustering(it, proc_data, cluster_type, n_clusters, variables, snap_lst)
        for key in grp_snap_dict.keys():
            if key not in it_dict:
                it_dict[key] = defaultdict(list)

            for metric in grp_snap_dict[key]:
                metric_lst = []
                for snap in snap_lst:
                    grp_snp_lst = np.array(grp_snap_dict[key]["snap"])
                    if snap not in grp_snp_lst:
                        metric_lst.append(np.nan)
                    else:
                        snp_msk = grp_snp_lst == snap
                        val = np.array(grp_snap_dict[key][metric])[snp_msk][0]
                        metric_lst.append(val)

                it_dict[key][metric].append(metric_lst)

    cluster_dict = {"snap": snap_lst, "time": time_lst, "groups": {}}

    # Add mean and std of each metric across iterations
    for key in it_dict.keys():
        if key == "ex_situ":
            cluster_dict[key] = {}
        else:
            cluster_dict["groups"][key] = {}
        for metric in it_dict[key].keys():
            if metric != "snap":
                if key == "ex_situ":
                    cluster_dict[key][f"{metric}_avg"] = np.nanmean(it_dict[key][metric], axis=0)
                    cluster_dict[key][f"{metric}_std"] = np.nanstd(it_dict[key][metric], axis=0)
                else:
                    cluster_dict["groups"][key][f"{metric}_avg"] = np.nanmean(it_dict[key][metric], axis=0)
                    cluster_dict["groups"][key][f"{metric}_std"] = np.nanstd(it_dict[key][metric], axis=0)

    cluster_dict["in_situ"] = {}
    for metric in cluster_dict["groups"]["0"].keys():
        cluster_dict["in_situ"][metric] = cluster_dict["groups"]["0"][metric]

    return cluster_dict

# %% [markdown]
# # Plotting

# %%
# i = 0
# it_lst = np.arange(it_min, it_max + 1)
# for it in it_lst:
#     it_id = gc_utils.iteration_name(it)
#     for snap_id in proc_data[it_id]["snapshots"].keys():
#         if int(snap_id[4:]) >= 46:
#             msk = proc_data[it_id]["snapshots"][snap_id]["now_accreted"][()] == 1
#             # ar = len(np.where(np.isnan(proc_data[it_id]["snapshots"][snap_id]["et_norm"][()]))[0])
#             ar = len(np.where(np.isnan(proc_data[it_id]["snapshots"][snap_id]["j.cyl"][:, 0][msk]))[0])
#             if ar > 0:
#                 print(it_id, snap_id)
#                 i += 1

# %%
# msk = proc_data["it003"]["snapshots"]["snap294"]["now_accreted"][()] == 1
# # proc_data["it003"]["snapshots"]["snap294"]["j.cyl"][:, 0][msk]
# np.where(np.isnan(proc_data["it003"]["snapshots"]["snap294"]["j.cyl"][:, 0][msk]))[0]

# %%
# proc_data["it003"]["snapshots"]["snap294"]["bound_flag"][msk][1222]

# %%
it_lst = np.arange(it_min, it_max + 1)

# for 101 iterations takes about 1 minute
# clsr_dict = iteration_clustering(it_lst, cluster_type, n_clusters, variables, sim, sim_dir, snap_lim)

# for 101 iterations takes about 1 minute
clsr_dct_grp = group_iteration_clustering(it_lst, cluster_type, n_clusters, variables, sim, sim_dir, snap_lim)
# Out:
# /var/folders/nb/byfjq48d6jz8b3g74s3zr7rh0000gp/T/ipykernel_49885/608825937.py:57: RuntimeWarning: Mean of empty slice
#   cluster_dict["groups"][key][f"{metric}_avg"] = np.nanmean(it_dict[key][metric], axis=0)
# /Users/z5114326/Documents/GitHub/gc_statistics/.venv/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
plt_err = True

x = clsr_dct_grp["time"]
yi = clsr_dct_grp["in_situ"]["f1_avg"]
ye = clsr_dct_grp["ex_situ"]["weight_f1_avg"]

plt.figure(figsize=(10, 6))
plt.plot(x, yi, c="r", label="In-Situ")
plt.plot(x, ye, c="b", label="Ex-Situ (Weighted)")

if plt_err:
    yi_err = clsr_dct_grp["in_situ"]["f1_std"]
    ye_err = clsr_dct_grp["ex_situ"]["weight_f1_std"]

    plt.fill_between(x, yi - yi_err, yi + yi_err, color="r", alpha=0.2)
    plt.fill_between(x, ye - ye_err, ye + ye_err, color="b", alpha=0.2)

plt.xlim(np.min(x), np.max(x))
plt.ylim(0, 1)

plt.xlabel("Time (Gyr)")
plt.ylabel("F1 - Score")

plt.legend()

# %%
# group_id = 19898495

# %%
grp_dict = {grp: {} for grp in grp_lst if grp != 0}

for grp in grp_dict.keys():
    log_num_gc = []

    et_norm_avg = []
    et_norm_std = []
    jr_avg = []
    jr_std = []
    jp_avg = []
    jp_std = []
    jz_avg = []
    jz_std = []

    com_avg = []
    com_spd_avg = []
    com_spd_std = []  # small means uniform structure, large means possibly clumpy

    for it in range(it_min, it_max + 1):
        it_id = gc_utils.iteration_name(it)
        snp_600 = proc_data[it_id]["snapshots"]["snap600"]
        grp_msk = snp_600["group_id"][()] == grp

        # conserved quantities
        et_norm = snp_600["et_norm"][grp_msk]
        jcyl = snp_600["j.cyl"][grp_msk]
        jr = jcyl[:, 0]
        jp = jcyl[:, 1]
        jz = jcyl[:, 2]

        # CoM
        xyz = snp_600["pos.xyz"][grp_msk]
        mass = 10 ** snp_600["mass"][grp_msk]

        c_x = np.sum(xyz[:, 0] * mass) / np.sum(mass)
        c_y = np.sum(xyz[:, 1] * mass) / np.sum(mass)
        c_z = np.sum(xyz[:, 2] * mass) / np.sum(mass)

        com = np.array([c_x, c_y, c_z])
        com_d = np.linalg.norm(com)

        # d_c = np.sqrt((c_x - xyz[:, 0]) ** 2 + (c_y - xyz[:, 1]) ** 2 + (c_z - xyz[:, 2]) ** 2)
        d_c = []
        for pos in xyz:
            d_c.append(ut.coordinate.get_distances(com, pos, total_distance=True))

        # append lists
        num_gc = len(et_norm)
        if num_gc == 0:
            continue

        log_num_gc.append(np.log10(num_gc))  # logged

        et_norm_avg.append(np.mean(et_norm))
        et_norm_std.append(np.std(et_norm))

        jr_avg.append(np.mean(np.log10(jr)))  # logged
        jr_std.append(np.std(np.log10(jr)))  # logged
        jp_avg.append(np.mean(jp))
        jp_std.append(np.std(jp))
        jz_avg.append(np.mean(np.log10(jz)))  # logged
        jz_std.append(np.std(np.log10(jz)))  # logged

        com_avg.append(com_d)
        com_spd_avg.append(np.mean(d_c))
        com_spd_std.append(np.std(d_c))

    # grp_dict[grp]["log_num_gc"] = np.nanmean(log_num_gc)

    # grp_dict[grp]["et_norm_avg"] = np.nanmean(et_norm_avg)
    # grp_dict[grp]["et_norm_std"] = np.nanmean(et_norm_std)

    # grp_dict[grp]["log_jr_avg"] = np.nanmean(jr_avg)
    # grp_dict[grp]["log_jr_std"] = np.nanmean(jr_std)
    # grp_dict[grp]["jp_avg"] = np.nanmean(jp_avg)
    # grp_dict[grp]["jp_std"] = np.nanmean(jp_std)
    # grp_dict[grp]["log_jz_avg"] = np.nanmean(jz_avg)
    # grp_dict[grp]["log_jz_std"] = np.nanmean(jz_std)

    # grp_dict[grp]["com_avg"] = np.nanmean(com_avg)
    # grp_dict[grp]["com_spd_avg"] = np.nanmean(com_spread_avg)
    # grp_dict[grp]["com_spd_std"] = np.nanmean(com_spread_std)

    weigh = 10 ** np.array(log_num_gc)

    grp_dict[grp]["log_num_gc"] = np.nanmean(log_num_gc)

    grp_dict[grp]["et_norm_avg"] = np.sum(weigh * np.array(et_norm_avg)) / np.sum(weigh)
    grp_dict[grp]["et_norm_std"] = np.sqrt(
        np.sum((weigh - 1) * np.array(et_norm_std) ** 2) / np.sum(weigh - 1)
    )

    grp_dict[grp]["log_jr_avg"] = np.sum(weigh * np.array(jr_avg)) / np.sum(weigh)
    grp_dict[grp]["log_jr_std"] = np.sqrt(np.sum((weigh - 1) * np.array(jr_std) ** 2) / np.sum(weigh - 1))
    grp_dict[grp]["jp_avg"] = np.sum(weigh * np.array(jp_avg)) / np.sum(weigh)
    grp_dict[grp]["jp_std"] = np.sqrt(np.sum((weigh - 1) * np.array(jp_std) ** 2) / np.sum(weigh - 1))
    grp_dict[grp]["log_jz_avg"] = np.sum(weigh * np.array(jz_avg)) / np.sum(weigh)
    grp_dict[grp]["log_jz_std"] = np.sqrt(np.sum((weigh - 1) * np.array(jz_std) ** 2) / np.sum(weigh - 1))

    grp_dict[grp]["com_avg"] = np.sum(weigh * np.array(com_avg)) / np.sum(weigh)
    grp_dict[grp]["com_spd_avg"] = np.sum(weigh * np.array(com_spd_avg)) / np.sum(weigh)
    grp_dict[grp]["com_spd_std"] = np.sqrt(
        np.sum((weigh - 1) * np.array(com_spd_std) ** 2) / np.sum(weigh - 1)
    )
# Out:
# /var/folders/nb/byfjq48d6jz8b3g74s3zr7rh0000gp/T/ipykernel_49885/629803012.py:35: RuntimeWarning: invalid value encountered in scalar divide
#   c_x = np.sum(xyz[:, 0] * mass) / np.sum(mass)
# /var/folders/nb/byfjq48d6jz8b3g74s3zr7rh0000gp/T/ipykernel_49885/629803012.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   c_y = np.sum(xyz[:, 1] * mass) / np.sum(mass)
# /var/folders/nb/byfjq48d6jz8b3g74s3zr7rh0000gp/T/ipykernel_49885/629803012.py:37: RuntimeWarning: invalid value encountered in scalar divide
halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_060.hdf5
#
# # in halo_analysis.halo_io.Particle():
# * read 5962 halos, 333 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_060.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 6161 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_061.hdf5
# * read 6161 halos, 327 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_061.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 6389 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_062.hdf5
# * read 6389 halos, 335 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_062.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 6625 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_063.hdf5
# * read 6625 halos, 319 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_063.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 6848 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_064.hdf5
# * read 6848 halos, 318 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_064.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 7057 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_065.hdf5
# * read 7057 halos, 316 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_065.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 7266 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_066.hdf5
# * read 7266 halos, 319 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_066.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 7503 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_067.hdf5
# * read 7503 halos, 319 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_067.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 7751 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_068.hdf5
# * read 7751 halos, 319 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_068.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 7967 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_069.hdf5
# * read 7967 halos, 308 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_069.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 8204 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_070.hdf5
# * read 8204 halos, 301 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_070.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 8446 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_071.hdf5
# * read 8446 halos, 307 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_071.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 8671 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_072.hdf5
# * read 8671 halos, 309 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_072.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 8871 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_073.hdf5
# * read 8871 halos, 305 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_073.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 9059 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_074.hdf5
# * read 9059 halos, 302 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_074.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 9354 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_075.hdf5
# * read 9354 halos, 307 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_075.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 9568 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_076.hdf5
# * read 9568 halos, 287 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_076.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 9832 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_077.hdf5
# * read 9832 halos, 301 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_077.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 10105 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_078.hdf5
# * read 10105 halos, 292 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_078.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 10339 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_079.hdf5
# * read 10339 halos, 277 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_079.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 10672 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_080.hdf5
# * read 10672 halos, 284 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_080.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 10897 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_081.hdf5
# * read 10897 halos, 288 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_081.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 11215 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_082.hdf5
# * read 11215 halos, 285 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_082.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 11536 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_083.hdf5
# * read 11536 halos, 278 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_083.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 11811 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_084.hdf5
# * read 11811 halos, 277 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_084.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 12006 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_085.hdf5
# * read 12006 halos, 279 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_085.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 12298 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_086.hdf5
# * read 12298 halos, 264 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_086.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 12568 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_087.hdf5
# * read 12568 halos, 262 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_087.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 12893 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_088.hdf5
# * read 12893 halos, 275 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_088.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 13089 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_089.hdf5
# * read 13089 halos, 264 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_089.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 13474 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_090.hdf5
# * read 13474 halos, 259 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_090.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 13707 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_091.hdf5
# * read 13707 halos, 254 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_091.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 13919 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_092.hdf5
# * read 13919 halos, 263 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_092.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 14244 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_093.hdf5
# * read 14244 halos, 252 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_093.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 14508 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_094.hdf5
# * read 14508 halos, 239 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_094.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 14790 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_095.hdf5
# * read 14790 halos, 239 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_095.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 15074 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_096.hdf5
# * read 15074 halos, 245 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_096.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 15348 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_097.hdf5
# * read 15348 halos, 246 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_097.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 15647 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_098.hdf5
# * read 15647 halos, 241 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_098.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 15951 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_099.hdf5
# * read 15951 halos, 232 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_099.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 16267 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_100.hdf5
# * read 16267 halos, 237 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_100.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 16497 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_101.hdf5
# * read 16497 halos, 240 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_101.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 16834 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_102.hdf5
# * read 16834 halos, 239 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_102.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 17286 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_103.hdf5
# * read 17286 halos, 227 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_103.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 17459 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_104.hdf5
# * read 17459 halos, 226 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_104.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 17900 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_105.hdf5
# * read 17900 halos, 224 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_105.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 18291 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_106.hdf5
# * read 18291 halos, 202 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_106.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 18505 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_107.hdf5
# * read 18505 halos, 207 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_107.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 18661 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_108.hdf5
# * read 18661 halos, 206 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_108.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 19127 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_109.hdf5
# * read 19127 halos, 211 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_109.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 19423 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_110.hdf5
# * read 19423 halos, 199 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_110.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 19929 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_111.hdf5
# * read 19929 halos, 200 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_111.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 20129 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_112.hdf5
# * read 20129 halos, 197 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_112.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 20324 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_113.hdf5
# * read 20324 halos, 193 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_113.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 20630 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_114.hdf5
# * read 20630 halos, 203 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_114.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 21198 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_115.hdf5
# * read 21198 halos, 197 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_115.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 21476 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_116.hdf5
# * read 21476 halos, 202 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_116.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 21736 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_117.hdf5
# * read 21736 halos, 195 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_117.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 22041 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_118.hdf5
# * read 22041 halos, 199 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_118.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 22286 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_119.hdf5
# * read 22286 halos, 205 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_119.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 22635 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_120.hdf5
# * read 22635 halos, 196 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_120.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 22962 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_121.hdf5
# * read 22962 halos, 194 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_121.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 23229 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_122.hdf5
# * read 23229 halos, 190 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_122.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 23515 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_123.hdf5
# * read 23515 halos, 201 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_123.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 23902 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_124.hdf5
# * read 23902 halos, 208 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_124.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 24248 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_125.hdf5
# * read 24248 halos, 213 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_125.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 24585 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_126.hdf5
# * read 24585 halos, 214 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_126.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 24907 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_127.hdf5
# * read 24907 halos, 200 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_127.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 25257 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_128.hdf5
# * read 25257 halos, 205 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_128.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 25684 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_129.hdf5
# * read 25684 halos, 199 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_129.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 26076 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_130.hdf5
# * read 26076 halos, 199 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_130.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 26516 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_131.hdf5
# * read 26516 halos, 196 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_131.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 26460 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_132.hdf5
# * read 26460 halos, 182 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_132.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 26858 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_133.hdf5
# * read 26858 halos, 187 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_133.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 27323 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_134.hdf5
# * read 27323 halos, 190 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_134.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 27686 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_135.hdf5
# * read 27686 halos, 190 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_135.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 28226 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_136.hdf5
# * read 28226 halos, 192 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_136.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 28202 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_137.hdf5
# * read 28202 halos, 192 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_137.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 28628 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_138.hdf5
# * read 28628 halos, 190 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_138.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 29159 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_139.hdf5
# * read 29159 halos, 191 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_139.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 29190 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_140.hdf5
# * read 29190 halos, 175 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_140.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 29800 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_141.hdf5
# * read 29800 halos, 180 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_141.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 30314 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_142.hdf5
# * read 30314 halos, 178 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_142.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 30270 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_143.hdf5
# * read 30270 halos, 183 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_143.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 30823 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_144.hdf5
# * read 30823 halos, 183 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_144.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 31456 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_145.hdf5
# * read 31456 halos, 186 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_145.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 31403 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_146.hdf5
# * read 31403 halos, 182 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_146.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 31960 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_147.hdf5
# * read 31960 halos, 181 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_147.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 31974 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_148.hdf5
# * read 31974 halos, 174 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_148.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 32641 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_149.hdf5
# * read 32641 halos, 173 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_149.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 32605 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_150.hdf5
# * read 32605 halos, 169 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_150.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 33361 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_151.hdf5
# * read 33361 halos, 166 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_151.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 33335 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_152.hdf5
# * read 33335 halos, 165 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_152.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 34145 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_153.hdf5
# * read 34145 halos, 171 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_153.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 34045 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_154.hdf5
# * read 34045 halos, 173 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_154.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 34868 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_155.hdf5
# * read 34868 halos, 174 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_155.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 34740 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_156.hdf5
# * read 34740 halos, 167 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_156.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35577 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_157.hdf5
# * read 35577 halos, 166 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_157.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35563 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_158.hdf5
# * read 35563 halos, 154 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_158.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36381 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_159.hdf5
# * read 36381 halos, 166 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_159.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36381 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_160.hdf5
# * read 36381 halos, 160 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_160.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 37203 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_161.hdf5
# * read 37203 halos, 157 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_161.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 37201 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_162.hdf5
# * read 37201 halos, 157 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_162.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 37172 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_163.hdf5
# * read 37172 halos, 160 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_163.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 38188 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_164.hdf5
# * read 38188 halos, 160 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_164.hdf5
# ...
#
#
# * read 36331 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_556.hdf5
# * read 36331 halos, 49 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_556.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36320 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_557.hdf5
# * read 36320 halos, 50 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_557.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36369 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_558.hdf5
# * read 36369 halos, 48 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_558.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36237 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_559.hdf5
# * read 36237 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_559.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36242 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_560.hdf5
# * read 36242 halos, 53 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_560.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36220 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_561.hdf5
# * read 36220 halos, 50 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_561.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36348 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_562.hdf5
# * read 36348 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_562.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36304 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_563.hdf5
# * read 36304 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_563.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36221 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_564.hdf5
# * read 36221 halos, 49 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_564.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36187 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_565.hdf5
# * read 36187 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_565.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36152 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_566.hdf5
# * read 36152 halos, 49 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_566.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36238 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_567.hdf5
# * read 36238 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_567.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36094 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_568.hdf5
# * read 36094 halos, 53 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_568.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36154 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_569.hdf5
# * read 36154 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_569.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36102 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_570.hdf5
# * read 36102 halos, 53 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_570.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36092 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_571.hdf5
# * read 36092 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_571.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36063 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_572.hdf5
# * read 36063 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_572.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36041 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_573.hdf5
# * read 36041 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_573.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36064 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_574.hdf5
# * read 36064 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_574.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36091 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_575.hdf5
# * read 36091 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_575.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36033 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_576.hdf5
# * read 36033 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_576.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35912 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_577.hdf5
# * read 35912 halos, 50 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_577.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35987 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_578.hdf5
# * read 35987 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_578.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36094 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_579.hdf5
# * read 36094 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_579.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 36073 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_580.hdf5
# * read 36073 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_580.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35994 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_581.hdf5
# * read 35994 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_581.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35869 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_582.hdf5
# * read 35869 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_582.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35855 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_583.hdf5
# * read 35855 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_583.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35870 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_584.hdf5
# * read 35870 halos, 51 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_584.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35897 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_585.hdf5
# * read 35897 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_585.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35820 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_586.hdf5
# * read 35820 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_586.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35769 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_587.hdf5
# * read 35769 halos, 55 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_587.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35796 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_588.hdf5
# * read 35796 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_588.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35791 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_589.hdf5
# * read 35791 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_589.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35915 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_590.hdf5
# * read 35915 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_590.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35912 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_591.hdf5
# * read 35912 halos, 52 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_591.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35854 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_592.hdf5
# * read 35854 halos, 53 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_592.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35871 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_593.hdf5
# * read 35871 halos, 53 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_593.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35935 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_594.hdf5
# * read 35935 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_594.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35880 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_595.hdf5
# * read 35880 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_595.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35890 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_596.hdf5
# * read 35890 halos, 54 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_596.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35886 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_597.hdf5
# * read 35886 halos, 53 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_597.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35848 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_598.hdf5
# * read 35848 halos, 55 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_598.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35882 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_599.hdf5
# * read 35882 halos, 57 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_599.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished
#
#
# * read 35838 halos from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/halo_600.hdf5
# * read 35838 halos, 55 have star particles, from:  Users/z5114326/Documents/simulations/m12i/m12i_res7100/halo/rockstar_dm/catalog_hdf5/star_600.hdf5
# * assigning primary host and coordinates wrt it to halo catalog...  finished

# %%
gc_prop_lst = [
    "log_num_gc",
    "et_norm_avg",
    "et_norm_std",
    "log_jr_avg",
    "log_jr_std",
    "jp_avg",
    "jp_std",
    "log_jz_avg",
    "log_jz_std",
    "com_avg",
    "com_spd_avg",
    "com_spd_std",
]

gal_prop_lst = [
    "t_quench",  # time galaxy made all its starts
    "t_quench_dis",  # time prior to t_dis galaxy made all its starts
    "t_quench_sat",  # time prior to t_dis galaxy made all its starts
    "t_sat",  # time galaxy first became a satellite
    "t_dis",  # time galaxy was no longer identified in halo finder
    "t_sat_t_dis",  # t_dis - t_sat
    "log_m_halo_sat",  # halo mass of galaxy when first became satellite
    "log_m_star_sat",  # stellar mass of galaxy when first became satellite
    "lx_sat",  # lx of galaxy when first became satellite
    "ly_sat",  # ly of galaxy when first became satellite
    "lz_sat",  # lz of galaxy when first became satellite
    "ltot_sat",  # l_tot of galaxy when first became satellite
    "log_ltot_sat",  # l_tot of galaxy when first became satellite
    "vel_circ_max_sat",  # max circular velocity of galaxy when first became satellite
    "log_vel_circ_max_sat",  # log of max circular velocity of galaxy when first became satellite
    "inc_sat",  # inclination of galaxy when first became satellite
]

gal_dict = {grp: {prop_str: {} for prop_str in gal_prop_lst} for grp in grp_lst if grp != 0}

# %%
for grp in grp_dict.keys():
    ###########################################
    tidx = np.where(halt["tid"] == grp)[0][0]
    pre_dis_snp = halt["snapshot"][tidx]

    # t_dis
    t_dis = all_snaps[all_snaps["index"] == pre_dis_snp + 1]["time_Gyr"].values[0]

    # t_qunch and t_quench_dis
    t_form_100 = 0
    for snap in range(50, pre_dis_snp):
        snp_tid = gc_utils.get_halo_prog_at_snap(halt, grp, snap)
        snp_tidx = np.where(halt["tid"] == snp_tid)[0][0]

        t_form_100_hold = halt["star.form.time.100"][snp_tidx]
        t_form_100 = np.max((t_form_100, t_form_100_hold))

    t_quench = t_form_100
    t_quench_dis = t_dis - t_quench

    # t_sat, t_quench_sat
    cidx = halt["catalog.index"][tidx]
    sat_snp = hals[pre_dis_snp]["infall.first.snapshot"][cidx]
    t_sat = all_snaps[all_snaps["index"] == sat_snp]["time_Gyr"].values[0]

    t_quench_sat = t_sat - t_quench

    # t_sat_t_dis
    t_sat_t_dis = t_dis - t_sat

    # m_halo_sat, m_star_sat
    sat_tid = gc_utils.get_halo_prog_at_snap(halt, grp, sat_snp)
    sat_tidx = np.where(halt["tid"] == sat_tid)[0][0]

    m_halo_sat = halt["mass"][sat_tidx]
    log_m_halo_sat = np.log10(m_halo_sat)

    m_star_sat = halt["star.mass"][sat_tidx]
    log_m_star_sat = np.log10(m_star_sat)

    # vel_circ_max_sat
    vel_circ_max_sat = halt["vel.circ.max"][sat_tidx]
    log_vel_circ_max_sat = np.log10(vel_circ_max_sat)

    # lx_sat, ly_sat, lz_sat, ltot_sat
    sat_pos_xyz = halt.prop("host.distance")[sat_tidx]
    sat_vel_xyz = halt.prop("host.velocity")[sat_tidx]

    lx_sat = sat_pos_xyz[1] * sat_vel_xyz[2] - sat_pos_xyz[2] * sat_vel_xyz[1]
    ly_sat = sat_pos_xyz[2] * sat_vel_xyz[0] - sat_pos_xyz[0] * sat_vel_xyz[2]
    lz_sat = sat_pos_xyz[0] * sat_vel_xyz[1] - sat_pos_xyz[1] * sat_vel_xyz[0]

    ltot_sat = np.linalg.norm([lx_sat, ly_sat, lz_sat])
    log_ltot_sat = np.log10(ltot_sat)

    # inc_sat
    inc_sat = np.degrees(np.arccos(lz_sat / ltot_sat))

    # add to dictionary
    for prop_str in gal_dict[grp].keys():
        prop = locals()[prop_str]
        gal_dict[grp][prop_str] = prop

# %%
consider_pvalue = True
pvalue_limit = 0.05
pre_disk_cut = False
# disk_form = 6

num_rows = len(gal_prop_lst)
num_cols = len(gc_prop_lst)

cor_arr = np.zeros(shape=(num_rows, num_cols))

for j, gal_prop in enumerate(gal_prop_lst):
    for i, gc_prop in enumerate(gc_prop_lst):
        gal_lst = []
        gc_lst = []
        for grp in grp_dict.keys():
            if (pre_disk_cut) & (gal_dict[grp]["t_dis"] <= disk_form):
                continue
            prop_hold = grp_dict[grp][gc_prop]
            if np.isnan(prop_hold):
                continue
            else:
                gc_lst.append(prop_hold)
                gal_lst.append(gal_dict[grp][gal_prop])

        p_stats = stats.pearsonr(gc_lst, gal_lst)
        cor_arr[j, i] = p_stats.statistic

        if (consider_pvalue) & (p_stats.pvalue > pvalue_limit):
            cor_arr[j, i] = np.nan

# %%
sig_lim = 0.9

plt.figure(figsize=(12, 10))
plt.imshow(cor_arr, vmin=-1, vmax=1, cmap="seismic")
plt.colorbar(label="Pearson Correlation")

plt.xticks(np.arange(0, len(gc_prop_lst)), gc_prop_lst, rotation=45, ha="right")
plt.yticks(np.arange(0, len(gal_prop_lst)), gal_prop_lst, rotation=45, ha="right")

for j, gal_prop in enumerate(gal_prop_lst):
    for i, gc_prop in enumerate(gc_prop_lst):
        if np.abs(cor_arr[j, i]) >= sig_lim:
            plt.scatter(i, j, c="w", s=50)

plt.show()

# %%
x = []
y = []
c = []

for grp in grp_dict.keys():
    if (pre_disk_cut) & (gal_dict[grp]["t_dis"] <= disk_form):
        continue

    # x.append(grp_dict[grp]["log_jz_avg"])
    # y.append(gal_dict[grp]["lx_sat"])

    x.append(grp_dict[grp]["log_jr_avg"])
    y.append(gal_dict[grp]["vel_circ_max_sat"])

    # x.append(grp_dict[grp]["log_jz_std"])
    # y.append(gal_dict[grp]["lx_sat"])

    c.append(gal_dict[grp]["t_sat"])

plt.scatter(x, y, c=c)

# plt.xlabel("log_jr_avg")
# plt.ylabel("vel_circ_max_sat")
plt.colorbar()

stats.pearsonr(x, y)
# Out:
# PearsonRResult(statistic=-0.912645285760918, pvalue=0.011112973959462664)
